# %% [markdown]
# ### Titanic Survival Exercises

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm


# %matplotlib inline
plt.style.use('seaborn-dark')

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].fillna(value=30.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.distplot(a=df.Age)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='Sex', data=df, hue='Age')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='Sex', data=df)
plt.show()

# %%
plt.figure(figsize=(20,15))
sm.qqplot(df.Age, line='q')
plt.show()

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Survived', y='Sex', data=df)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.countplot(x=df.Age, hue=df.Survived)
plt.xticks(rotation=90)
plt.show()

# %%
df['Fare'].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 8.4583      1
# 9.8375      1
# 8.3625      1
# 14.1083     1
# 17.4000     1
# Name: Fare, Length: 248, dtype: int64

# %%
df2 = df[df['Fare'] != 0]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2['farelog'] = np.log(df2.Fare)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x='Survived', y='Fare', data=df2)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.boxplot(x='farelog', data=df2, orient='v', hue=df2.Survived)
plt.subplot(1,2,2)
sns.boxplot(x='farelog', data=df2, orient='v', hue=df2.Survived == 1)

# %%
df2['Fare'].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 32.3208     1
# 13.8583     1
# 7.6292      1
# 15.0500     1
# 8.6833      1
# Name: Fare, Length: 247, dtype: int64

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   876.000000  876.000000  876.000000  876.000000  876.000000
# mean    444.794521    0.389269    2.315068   29.713664    0.531963
# std     257.806393    0.487863    0.835663   13.078290    1.110009
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     220.750000    0.000000    2.000000   22.000000    0.000000
# 50%     444.500000    0.000000    3.000000   30.000000    0.000000
# 75%     667.250000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare     farelog
# count  876.000000  876.000000  876.000000
# mean     0.388128   32.755650    2.943398
# std      0.811374   49.936826    0.936499
# min      0.000000    4.012500    1.389414
# 25%      0.000000    7.925000    2.070022
# 50%      0.000000   14.500000    2.674149
# 75%      0.000000   31.275000    3.442819
# ...

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x='Survived', y='Pclass', data=df)
plt.show()

# %%
216+184
# Out:
# 400

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='Pclass', data=df, hue='Survived')
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x='Survived', y='Age', hue='Sex', data=df)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.pairplot(data=df)
plt.show()

# %%
sns.catplot(x='Age',y='Sex',col='Survived',row='Pclass', data=df)
plt.show()
