# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("movielens.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    movieId                                    title    year  \
# 0       31                          Dangerous Minds  1995.0
# 1     1029                                    Dumbo  1941.0
# 2     1061                                 Sleepers  1996.0
# 3     1129                     Escape from New York  1981.0
# 4     1172  Cinema Paradiso (Nuovo cinema Paradiso)  1989.0
#
#                              genres  userId  rating   timestamp
# 0                             Drama       1     2.5  1260759144
# 1  Animation|Children|Drama|Musical       1     3.0  1260759179
# 2                          Thriller       1     3.0  1260759182
# 3  Action|Adventure|Sci-Fi|Thriller       1     2.0  1260759185
# 4                             Drama       1     4.0  1260759205

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 7 columns):
# movieId      100004 non-null int64
# title        99997 non-null object
# year         99997 non-null float64
# genres       100004 non-null object
# userId       100004 non-null int64
# rating       100004 non-null float64
# timestamp    100004 non-null int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 5.3+ MB

# %%
df.shape
# Out:
# (100004, 7)

# %%
df.describe()
# Out:
#              movieId          year         userId         rating     timestamp
# count  100004.000000  99997.000000  100004.000000  100004.000000  1.000040e+05
# mean    12548.664363   1991.827305     347.011310       3.543608  1.129639e+09
# std     26369.198969     15.088703     195.163838       1.058064  1.916858e+08
# min         1.000000   1902.000000       1.000000       0.500000  7.896520e+08
# 25%      1028.000000   1987.000000     182.000000       3.000000  9.658478e+08
# 50%      2406.500000   1995.000000     367.000000       4.000000  1.110422e+09
# 75%      5418.000000   2001.000000     520.000000       4.000000  1.296192e+09
# max    163949.000000   2016.000000     671.000000       5.000000  1.476641e+09

# %%
median = df[df['rating'] == 4.0]

# %%
median
# Out:
#         movieId                                    title    year  \
# 4          1172  Cinema Paradiso (Nuovo cinema Paradiso)  1989.0
# 12         1953                   French Connection, The  1971.0
# 13         2105                                     Tron  1982.0
# 20           10                                GoldenEye  1995.0
# 23           47                     Seven (a.k.a. Se7en)  1995.0
# ...         ...                                      ...     ...
# 99992      5816  Harry Potter and the Chamber of Secrets  2002.0
# 99995      5989                      Catch Me If You Can  2002.0
# 99997      5995                             Pianist, The  2002.0
# 100000     6269                                   Stevie  2002.0
# 100001     6365                     Matrix Reloaded, The  2003.0
#
#                                        genres  userId  rating   timestamp
# 4                                       Drama       1     4.0  1260759205
# ...

# %%
median['year'].value_counts() #What year has the highest median number of ratings?
# Out:
# 1995.0    1922
# 1994.0    1656
# 1996.0    1481
# 1999.0    1419
# 1993.0    1273
#           ...
# 1923.0       2
# 1921.0       2
# 1918.0       1
# 1917.0       1
# 1902.0       1
# Name: year, Length: 99, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='year',y='rating',data=df)
plt.show()

# %%
shaw = df[df['title'] == 'Shawshank Redemption, The']

# %%
shaw
# Out:
#        movieId                      title    year       genres  userId  \
# 101        318  Shawshank Redemption, The  1994.0  Crime|Drama       3
# 511        318  Shawshank Redemption, The  1994.0  Crime|Drama       7
# 591        318  Shawshank Redemption, The  1994.0  Crime|Drama       8
# 704        318  Shawshank Redemption, The  1994.0  Crime|Drama       9
# 746        318  Shawshank Redemption, The  1994.0  Crime|Drama      10
# ...        ...                        ...     ...          ...     ...
# 98764      318  Shawshank Redemption, The  1994.0  Crime|Drama     664
# 99297      318  Shawshank Redemption, The  1994.0  Crime|Drama     665
# 99802      318  Shawshank Redemption, The  1994.0  Crime|Drama     668
# 99867      318  Shawshank Redemption, The  1994.0  Crime|Drama     670
# 99895      318  Shawshank Redemption, The  1994.0  Crime|Drama     671
#
#        rating   timestamp
# 101       5.0  1298862121
# 511       5.0   851868187
# 591       5.0  1154464714
# ...

# %%
shaw['rating'].mean() #What is the average rating for the movie The Shawshank Redemption?
# Out:
# 4.487138263665595

# %%
forrest = df[df['title'] == 'Forrest Gump']

# %%
forrest
# Out:
#        movieId         title    year                    genres  userId  \
# 57         356  Forrest Gump  1994.0  Comedy|Drama|Romance|War       2
# 103        356  Forrest Gump  1994.0  Comedy|Drama|Romance|War       3
# 159        356  Forrest Gump  1994.0  Comedy|Drama|Romance|War       4
# 359        356  Forrest Gump  1994.0  Comedy|Drama|Romance|War       5
# 516        356  Forrest Gump  1994.0  Comedy|Drama|Romance|War       7
# ...        ...           ...     ...                       ...     ...
# 98766      356  Forrest Gump  1994.0  Comedy|Drama|Romance|War     664
# 99302      356  Forrest Gump  1994.0  Comedy|Drama|Romance|War     665
# 99712      356  Forrest Gump  1994.0  Comedy|Drama|Romance|War     666
# 99772      356  Forrest Gump  1994.0  Comedy|Drama|Romance|War     667
# 99896      356  Forrest Gump  1994.0  Comedy|Drama|Romance|War     671
#
#        rating   timestamp
# 57        3.0   835355628
# 103       5.0  1298862167
# 159       5.0   949919763
# ...

# %%
forrest['year'].value_counts()
# Out:
# 1994.0    341
# Name: year, dtype: int64

# %%
yearrange = 2016 - 1994
yearrange
# Out:
# 22

# %%
forrest['rating'].sum() / yearrange #What is the average number of ratings per year for the movie Forrest Gump?
# Out:
# 62.84090909090909

# %%
df['title'].unique()
# Out:
# array(['Dangerous Minds', 'Dumbo', 'Sleepers', ..., 'Pie in the Sky',
#        'Summer Catch', '6th Man, The (Sixth Man, The)'], dtype=object)

# %%
df['title'].nunique()
# Out:
# 8831

# %%
lowest = df[df['rating'] == 0.5]

# %%
lowest
# Out:
#        movieId                              title    year  \
# 466       1876                        Deep Impact  1998.0
# 615       1358                        Sling Blade  1996.0
# 984         70                From Dusk Till Dawn  1996.0
# 1001       160                              Congo  1995.0
# 1053       355                   Flintstones, The  1994.0
# ...        ...                                ...     ...
# 96345     8387  Police Academy: Mission to Moscow  1994.0
# 97581     1037                 Lawnmower Man, The  1992.0
# 98536      593          Silence of the Lambs, The  1991.0
# 98626      637                         Sgt. Bilko  1996.0
# 98649     4483                      Caddyshack II  1988.0
#
#                                 genres  userId  rating   timestamp
# 466              Drama|Sci-Fi|Thriller       6     0.5  1108134334
# 615                              Drama       8     0.5  1154474527
# ...

# %%
lowest['genres'].value_counts()
# Out:
# Comedy                                 105
# Comedy|Romance                          58
# Drama                                   47
# Action|Adventure|Sci-Fi                 31
# Drama|Romance                           29
#                                       ...
# (no genres listed)                       1
# Crime|Drama|Mystery                      1
# Children|Drama                           1
# Action|Sci-Fi|Thriller|Western|IMAX      1
# Drama|Fantasy|Romance|Thriller           1
# Name: genres, Length: 284, dtype: int64

# %%
#Which genre has the lowest average rating?
plt.figure(figsize=(20,10))
sns.countplot(x='genres', data=lowest, order=lowest['genres'].value_counts().index[:10])
plt.xticks(rotation=90)
plt.show()
