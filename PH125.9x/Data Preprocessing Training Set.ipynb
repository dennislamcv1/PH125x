# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from pandas_profiling import ProfileReport

pd.set_option('display.max_rows',10000)

# %%
df = pd.read_csv("edx2.csv", low_memory=False)

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp                          title      G1  \
# 0       1      122     5.0  838985046               Boomerang (1992)  Comedy
# 1       1      185     5.0  838983525                Net, The (1995)  Action
# 2       1      292     5.0  838983421                Outbreak (1995)  Action
# 3       1      316     5.0  838983392                Stargate (1994)  Action
# 4       1      329     5.0  838983392  Star Trek: Generations (1994)  Action
#
#           G2        G3        G4   G5   G6   G7   G8
# 0    Romance       NaN       NaN  NaN  NaN  NaN  NaN
# 1      Crime  Thriller       NaN  NaN  NaN  NaN  NaN
# 2      Drama    Sci-Fi  Thriller  NaN  NaN  NaN  NaN
# 3  Adventure    Sci-Fi       NaN  NaN  NaN  NaN  NaN
# 4  Adventure     Drama    Sci-Fi  NaN  NaN  NaN  NaN

# %%
df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  9.000055e+06  9.000055e+06  9.000055e+06  9.000055e+06
# mean   3.586982e+04  4.121702e+03  3.512465e+00  1.032616e+09
# std    2.058525e+04  8.942108e+03  1.060331e+00  1.159668e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    1.812400e+04  6.480000e+02  3.000000e+00  9.467683e+08
# 50%    3.573800e+04  1.834000e+03  4.000000e+00  1.035494e+09
# 75%    5.360700e+04  3.626000e+03  4.000000e+00  1.126751e+09
# max    7.156700e+04  6.513300e+04  5.000000e+00  1.231132e+09

# %%
df2 = df.drop(['userId','timestamp','title'],axis=1)

# %%
df2.shape
# Out:
# (9000055, 10)

# %%
df2.head()
# Out:
#    movieId  rating      G1         G2        G3        G4   G5   G6   G7   G8
# 0      122     5.0  Comedy    Romance       NaN       NaN  NaN  NaN  NaN  NaN
# 1      185     5.0  Action      Crime  Thriller       NaN  NaN  NaN  NaN  NaN
# 2      292     5.0  Action      Drama    Sci-Fi  Thriller  NaN  NaN  NaN  NaN
# 3      316     5.0  Action  Adventure    Sci-Fi       NaN  NaN  NaN  NaN  NaN
# 4      329     5.0  Action  Adventure     Drama    Sci-Fi  NaN  NaN  NaN  NaN

# %%
df3 = df2.sort_values(by=['movieId'])

# %%
df3
# Out:
#          movieId  rating         G1         G2        G3      G4       G5  \
# 2235296        1     5.0  Adventure  Animation  Children  Comedy  Fantasy
# 2162345        1     4.0  Adventure  Animation  Children  Comedy  Fantasy
# 8824951        1     5.0  Adventure  Animation  Children  Comedy  Fantasy
# 5691405        1     3.5  Adventure  Animation  Children  Comedy  Fantasy
# 6694822        1     4.0  Adventure  Animation  Children  Comedy  Fantasy
# ...          ...     ...        ...        ...       ...     ...      ...
# 5110549    65133     2.0     Comedy        NaN       NaN     NaN      NaN
# 8555249    65133     5.0     Comedy        NaN       NaN     NaN      NaN
# 368897     65133     2.0     Comedy        NaN       NaN     NaN      NaN
# 4205307    65133     3.0     Comedy        NaN       NaN     NaN      NaN
# 5723873    65133     2.5     Comedy        NaN       NaN     NaN      NaN
#
#           G6   G7   G8
# 2235296  NaN  NaN  NaN
# 2162345  NaN  NaN  NaN
# 8824951  NaN  NaN  NaN
# 5691405  NaN  NaN  NaN
# 6694822  NaN  NaN  NaN
# ...      ...  ...  ...
# 5110549  NaN  NaN  NaN
# 8555249  NaN  NaN  NaN
# 368897   NaN  NaN  NaN
# 4205307  NaN  NaN  NaN
# 5723873  NaN  NaN  NaN
#
# [9000055 rows x 10 columns]

# %%
df3.reset_index(inplace=True)

# %%
df3
# Out:
#            index  movieId  rating         G1         G2        G3      G4  \
# 0        2235296        1     5.0  Adventure  Animation  Children  Comedy
# 1        2162345        1     4.0  Adventure  Animation  Children  Comedy
# 2        8824951        1     5.0  Adventure  Animation  Children  Comedy
# 3        5691405        1     3.5  Adventure  Animation  Children  Comedy
# 4        6694822        1     4.0  Adventure  Animation  Children  Comedy
# ...          ...      ...     ...        ...        ...       ...     ...
# 9000050  5110549    65133     2.0     Comedy        NaN       NaN     NaN
# 9000051  8555249    65133     5.0     Comedy        NaN       NaN     NaN
# 9000052   368897    65133     2.0     Comedy        NaN       NaN     NaN
# 9000053  4205307    65133     3.0     Comedy        NaN       NaN     NaN
# 9000054  5723873    65133     2.5     Comedy        NaN       NaN     NaN
#
#               G5   G6   G7   G8
# 0        Fantasy  NaN  NaN  NaN
# 1        Fantasy  NaN  NaN  NaN
# 2        Fantasy  NaN  NaN  NaN
# 3        Fantasy  NaN  NaN  NaN
# 4        Fantasy  NaN  NaN  NaN
# ...          ...  ...  ...  ...
# 9000050      NaN  NaN  NaN  NaN
# 9000051      NaN  NaN  NaN  NaN
# 9000052      NaN  NaN  NaN  NaN
# 9000053      NaN  NaN  NaN  NaN
# 9000054      NaN  NaN  NaN  NaN
#
# [9000055 rows x 11 columns]

# %%
df3 = df3.drop(['index'],axis=1)

# %%
df3
# Out:
#          movieId  rating         G1         G2        G3      G4       G5  \
# 0              1     5.0  Adventure  Animation  Children  Comedy  Fantasy
# 1              1     4.0  Adventure  Animation  Children  Comedy  Fantasy
# 2              1     5.0  Adventure  Animation  Children  Comedy  Fantasy
# 3              1     3.5  Adventure  Animation  Children  Comedy  Fantasy
# 4              1     4.0  Adventure  Animation  Children  Comedy  Fantasy
# ...          ...     ...        ...        ...       ...     ...      ...
# 9000050    65133     2.0     Comedy        NaN       NaN     NaN      NaN
# 9000051    65133     5.0     Comedy        NaN       NaN     NaN      NaN
# 9000052    65133     2.0     Comedy        NaN       NaN     NaN      NaN
# 9000053    65133     3.0     Comedy        NaN       NaN     NaN      NaN
# 9000054    65133     2.5     Comedy        NaN       NaN     NaN      NaN
#
#           G6   G7   G8
# 0        NaN  NaN  NaN
# 1        NaN  NaN  NaN
# 2        NaN  NaN  NaN
# 3        NaN  NaN  NaN
# 4        NaN  NaN  NaN
# ...      ...  ...  ...
# 9000050  NaN  NaN  NaN
# 9000051  NaN  NaN  NaN
# 9000052  NaN  NaN  NaN
# 9000053  NaN  NaN  NaN
# 9000054  NaN  NaN  NaN
#
# [9000055 rows x 10 columns]

# %%
df3.groupby(by=['movieId','rating']).count()
# Out:
#                  G1   G2   G3   G4   G5  G6  G7  G8
# movieId rating
# 1       0.5      73   73   73   73   73   0   0   0
#         1.0     267  267  267  267  267   0   0   0
#         1.5      96   96   96   96   96   0   0   0
#         2.0     716  716  716  716  716   0   0   0
#         2.5     408  408  408  408  408   0   0   0
# ...             ...  ...  ...  ...  ...  ..  ..  ..
# 65130   2.5       1    1    0    0    0   0   0   0
# 65133   2.0       2    0    0    0    0   0   0   0
#         2.5       1    0    0    0    0   0   0   0
#         3.0       1    0    0    0    0   0   0   0
#         5.0       2    0    0    0    0   0   0   0
#
# [88255 rows x 8 columns]

# %%
df4 = df3.groupby(by=['movieId','rating']).count()

# %%
df4.head()
# Out:
#                  G1   G2   G3   G4   G5  G6  G7  G8
# movieId rating
# 1       0.5      73   73   73   73   73   0   0   0
#         1.0     267  267  267  267  267   0   0   0
#         1.5      96   96   96   96   96   0   0   0
#         2.0     716  716  716  716  716   0   0   0
#         2.5     408  408  408  408  408   0   0   0

# %%
df4.columns
# Out:
# Index(['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8'], dtype='object')

# %%
df4.reset_index(inplace=True)

# %%
df4.columns
# Out:
# Index(['movieId', 'rating', 'G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8'], dtype='object')

# %%
df4.head()
# Out:
#    movieId  rating   G1   G2   G3   G4   G5  G6  G7  G8
# 0        1     0.5   73   73   73   73   73   0   0   0
# 1        1     1.0  267  267  267  267  267   0   0   0
# 2        1     1.5   96   96   96   96   96   0   0   0
# 3        1     2.0  716  716  716  716  716   0   0   0
# 4        1     2.5  408  408  408  408  408   0   0   0

# %%
df4.drop(['G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8'],axis=1,inplace=True)

# %%
df4
# Out:
#        movieId  rating   G1
# 0            1     0.5   73
# 1            1     1.0  267
# 2            1     1.5   96
# 3            1     2.0  716
# 4            1     2.5  408
# ...        ...     ...  ...
# 88250    65130     2.5    1
# 88251    65133     2.0    2
# 88252    65133     2.5    1
# 88253    65133     3.0    1
# 88254    65133     5.0    2
#
# [88255 rows x 3 columns]

# %%
df4.rename(columns={"G1":'count'},inplace=True)

# %%
df4
# Out:
#        movieId  rating  count
# 0            1     0.5     73
# 1            1     1.0    267
# 2            1     1.5     96
# 3            1     2.0    716
# 4            1     2.5    408
# ...        ...     ...    ...
# 88250    65130     2.5      1
# 88251    65133     2.0      2
# 88252    65133     2.5      1
# 88253    65133     3.0      1
# 88254    65133     5.0      2
#
# [88255 rows x 3 columns]

# %%
df4.head()
# Out:
#    movieId  rating  count
# 0        1     0.5     73
# 1        1     1.0    267
# 2        1     1.5     96
# 3        1     2.0    716
# 4        1     2.5    408

# %%
df4.rename(columns={"Count":'count'},inplace=True)

# %%
df4.head()
# Out:
#    movieId  rating  count
# 0        1     0.5     73
# 1        1     1.0    267
# 2        1     1.5     96
# 3        1     2.0    716
# 4        1     2.5    408

# %%
#Rearrange the columns
df4 = df4[['movieId','count','rating']]

# %%
df4.head()
# Out:
#    movieId  count  rating
# 0        1     73     0.5
# 1        1    267     1.0
# 2        1     96     1.5
# 3        1    716     2.0
# 4        1    408     2.5

# %%
df4.shape
# Out:
# (88255, 3)

# %%
#Save to csv
#df4.to_csv("train.csv",index=False)

# %%
profile = ProfileReport(df4,title='Pandas Profiling Report')

# %%
profile
# Out:
# Tab(children=(HTML(value='<div id="overview-content" class="row variable spacing">\n    <div class="row">\n   …
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.
